# %%
import pandas as pd

# %%
df = pd.read_csv('cleaned_data2.csv')

# %%
df
# Out:
#            num                                               name  \
# 0      9251120                             maybe.this.time.(2014)
# 1      9211589  down.the.shore.s01.e10.and.justice.for.all.(1992)
# 2      9380845       uncontrollably.fond.s01.e07.heartache.(2016)
# 3      9301436       screen.two.s13.e04.the.precious.blood.(1996)
# 4      9408707                                  battlebots.(2015)
# ...        ...                                                ...
# 16495  9418128             saranghanda.saranghaji.anneunda.(2011)
# 16496  9238476  slasher.s01.e04.as.water.is.corrupted.unless.i...
# 16497  9413962  naruto.shippuden.s01.e136.mangekyo.sharingan.n...
# 16498  9229663     tales.of.the.walking.dead.s01.e05.davon.(2022)
# 16499  9391856                                      avatar.(2009)
#
#                                       clean_file_content
# 0      watch video online opensubtitles free browser ...
# 1      oh know getting late dont wan na go home im hu...
# 2      itiming subtitle uncontrollable lovebird team ...
# 3      ethereal music apiopensubtitlesorg deprecated ...
# 4      chris oh minibots yelling oh leave little bot ...
# ...                                                  ...
# 16495  advertise product brand contact wwwopensubtitl...
# 16496  phone ringing ipreviously slasheri cant stay r...
# 16497  support u become vip member remove ad wwwopens...
# 16498  man davon wheres boy groaning gasping wheezing...
# 16499  script info script generated aegisub title ava...
#
# [16500 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16500 entries, 0 to 16499
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   num                 16500 non-null  int64
#  1   name                16500 non-null  object
#  2   clean_file_content  16500 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 386.8+ KB

# %%
df['num'] = df['num'].apply(lambda x : str(x)) #converting 'num' id to string as chromaDB ids need to be in string format

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16500 entries, 0 to 16499
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   num                 16500 non-null  object
#  1   name                16500 non-null  object
#  2   clean_file_content  16500 non-null  object
# dtypes: object(3)
# memory usage: 386.8+ KB

# %%
#!pip install sentence-transformers

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

model_name = 'paraphrase-MiniLM-L3-v2' #all-MiniLM-L6-v2
model = SentenceTransformer(model_name, device='cpu')

# %%
def semantic_chunking(document, similarity_threshold=0.9):

    # Tokenize the document into sentences
    sentences = document.split('.')

    # Initialize variables for semantic chunks
    chunks = []
    current_chunk = sentences[0]

    # Generate embeddings for the sentences
    sentence_embeddings = model.encode(sentences)

    # Iterate over the sentences and group semantically similar sentences into chunks
    for i in range(1, len(sentences)):
        # Calculate cosine similarity between the current sentence and the previous sentence
        similarity_score = np.dot(sentence_embeddings[i], sentence_embeddings[i-1]) / (np.linalg.norm(sentence_embeddings[i]) * np.linalg.norm(sentence_embeddings[i-1]))

        # If similarity score is above the threshold, add the sentence to the current chunk
        if similarity_score >= similarity_threshold:
            current_chunk += '.' + sentences[i]
        else:
            # If similarity score is below the threshold, start a new chunk
            chunks.append(current_chunk)
            current_chunk = sentences[i]

    # Add the last chunk
    chunks.append(current_chunk)

    return chunks

# %%
# temporary dataframes to split the data into two parts

temp_1 = pd.DataFrame()
temp_2 = pd.DataFrame()

# %%
temp_1['num']=df['num'][:8250]

# %%
temp_2['num']=df['num'][8250:]

# %%
# 1st section using joblib for parallel processing on the first part of the data

from joblib import Parallel, delayed
import time
start = time.time()
temp_1['chunks'] = Parallel(n_jobs=-1)(delayed(semantic_chunking)(item) for item in df['clean_file_content'].values[:8250])
end=time.time()
print(f"Total time in seconds = {end-start}")
# Out:
# Total time in seconds = 1786.451331615448

# %%
#saving to json file

temp_1.to_json("database.json") #saving data to json file to restrart the kernel and save RAM

# %%
# 2nd section - using joblib for parallel processing on the second part of the data
from joblib import Parallel, delayed
import time
start = time.time()
temp_2['chunks'] = Parallel(n_jobs=-1)(delayed(semantic_chunking)(item) for item in df['clean_file_content'].values[8250:])
end=time.time()
print(f"Total time in seconds = {end-start}")
# Out:
# Total time in seconds = 1762.5092811584473

# %%
temp_2.to_json("database_p2.json") #saving data to json file to restrart the kernel and save RAM

# %%
# restarting the kernel
# interacting with each part of the json file

import json

json_file_path = "database.json" #database_p2.json
with open(json_file_path, 'r') as f:
  data = json.load(f)

df = pd.DataFrame(data)

# %%
df
# Out:
#           num                                             chunks
# 0     9251120  [watch video online opensubtitles free browser...
# 1     9211589  [oh know getting late dont wan na go home im h...
# 2     9380845  [itiming subtitle uncontrollable lovebird team...
# 3     9301436  [ethereal music apiopensubtitlesorg deprecated...
# 4     9408707  [chris oh minibots yelling oh leave little bot...
# ...       ...                                                ...
# 8245  9194538  [watch video online opensubtitles free browser...
# 8246  9461187  [hey twizzle meow hey twizzle twizzle girl huh...
# 8247  9309873  [script info title english u original script t...
# 8248  9255721  [life span link eternity begun must end advert...
# 8249  9485784  [advertise product brand contact wwwopensubtit...
#
# [8250 rows x 2 columns]

# %%
df['chunks'][0] # First row of chunked data
# Out:
# C:\Users\shetk\AppData\Local\Temp\ipykernel_17300\113786587.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['chunks'][0] # First row of chunked data
# ['watch video online opensubtitles free browser extension osdblinkext iit couldve another summeri ibut set foot sandi ithat summer suddenly felt differenti ilike going summeri ithat would change lifei ithe summer freedomi ithe summer endless possibilitiesi ithe summer ooh aah ooh oh oh oh ooh ithat summer mei youre quite dancer stop come keep dancing whatever im kidding dont get mad huh hey im going get towel stop thought gon na kiss excuse wan na kiss yet mean yet youre girl mean girl girlfriend miss wish dont call miss dont pretend gentleman youre clearly call rude snob bitch douche handsome conceited like huh jerk exactly type leave alone steph aha steph ill call tep remove f way im tonio still tomorrow dont leave yet im going court ii chose walk away youi ibut fate different plani councilor teaching basic english literacy well teaching child read write english yes long program run okay entire summer ii thought could escape youi ibut somehow found againi tep couldnt resist huh youre courting instead excuse im court oh youre courted yeah uncle tonio shes one teach u summer dont believe story thats excuse get date gramps uncle erning aunt elma tep suitor approved approved passed mmm dont approve excuse u well going right dear thank sir well go ahead excuse please oh tep tep okay said excuse yet couple already fighting point oh tonio seventy snack seven seven silvery silvery sheep sheep know filipino filipino seventyseven silvery sheep say english say filipino need learn read write speak properly order make living anyway tep dont need learn make living instead seventyseven slippery say instead teaching teach swim sinking boat english proficiency wont save youll dead youre well aware thats part lesson disturbing u irritable hotheaded maybe go swimming sound fun hey kid wan na go swimming yes swimming swimming swimming okay really want swim wan na swim let go first thats want swimming swimming hey tonio swimming swimming put swimming swimming want huh wait minute wait hugging want badly huh course huh hey stop come take tep happened oh uncle tonio stepped sea urchin iyou saved mei iyou cared mei iand made feel alivei tep tried ive never seen caramel flan used bread filling taste youll surely fall love really yeah would thought may unlucky finding job youre lucky finding girlfriend look good together heard look good together mean couple mmm quick havent officially courted yet court well save ago course would save id rather get hurt see get hurt court mmm fine sure yes ouch whyd im okay sure okay thank kiss huh kiss im talking bread oh whatever kiss surprised mmm good mmm good told slowly mmhm almost okay yet yeah keep eye closed mmhm one two three wow beautiful tonio like yes know favorite spot town fact beautiful thing ive ever seen mmm saw nice wow youre teasing true ive got one surprise there yes look okay whats blow blow yeah oh cute give hand dont money buy flower got instead tep starting courting okay buy pretty made made yes really made yeah want see made sure wow beautiful made wow youve long time dad started also developed knack know tep enough money working seaman want set furniture shop father dream really wow ill first customer wait question use old wood dont like seeing piece driftwood go waste people see rotten old useless really stop look thats see true beauty unfortunately many people lot people think junk throw away like trash iyou captivated mei ithrough beauty dreamsi iand kindness hearti iand slowly surely falling youi ah sorry sorry hurt sorry ievery moment spent togetheri ifelt like happily ever afteri wont take long tep cook special chicken skewer tonio huh hey erasing heart tonio love tep vice versa teptep love tonio know love right know wont admit tep see mmm like like let go let go ii didnt know goingi ibut happy wherever werei hold tight oops start paddling serious im kidding come okay tired little bit hey steph steph brother okay family daddy suddenly given surprised vacation leave porky hi maam hi sir ...

# %% [markdown]
# ## Generating Text Embeddings

# %% [markdown]
# ### Part 1: Preparing the indexes

# %%
def indexer(item):
    index=[]
    temp=int(df[df['num']==item].index[0])
    for j in range(len(df['chunks'].iloc[temp])):
        index.append(item+"-"+str(j))# since id needs to be unique adding the j index with a hyphen to create a unique id
    return index

# %%
df['num_list'] = df['num'].apply(lambda x : indexer(x)) #indexing the embeddings

# %%
df
# Out:
#           num                                             chunks     num_list
# 0     9251120  [watch video online opensubtitles free browser...  [9251120-0]
# 1     9211589  [oh know getting late dont wan na go home im h...  [9211589-0]
# 2     9380845  [itiming subtitle uncontrollable lovebird team...  [9380845-0]
# 3     9301436  [ethereal music apiopensubtitlesorg deprecated...  [9301436-0]
# 4     9408707  [chris oh minibots yelling oh leave little bot...  [9408707-0]
# ...       ...                                                ...          ...
# 8245  9194538  [watch video online opensubtitles free browser...  [9194538-0]
# 8246  9461187  [hey twizzle meow hey twizzle twizzle girl huh...  [9461187-0]
# 8247  9309873  [script info title english u original script t...  [9309873-0]
# 8248  9255721  [life span link eternity begun must end advert...  [9255721-0]
# 8249  9485784  [advertise product brand contact wwwopensubtit...  [9485784-0]
#
# [8250 rows x 3 columns]

# %%
df['num_list'][0]
# Out:
# C:\Users\shetk\AppData\Local\Temp\ipykernel_17300\3890957039.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['num_list'][0]
# ['9251120-0']

# %% [markdown]
# ### Part 2: Creating the text embeddings

# %%
from sentence_transformers import SentenceTransformer

model_name = 'paraphrase-MiniLM-L3-v2' #all-MiniLM-L6-v2
model = SentenceTransformer(model_name, device='cpu')

# %%
def embedding_gen(data):
  return model.encode(data).tolist()

# %%
from joblib import Parallel, delayed
import time
start = time.time()
df['embeddings'] = Parallel(n_jobs=-1)(delayed(embedding_gen)(item) for item in df['chunks'].values)
end = time.time()
print(f"Total time in seconds = {end-start}")
# Out:
# Total time in seconds = 1719.1567568778992

# %%
df
# Out:
#           num                                             chunks     num_list  \
# 0     9251120  [watch video online opensubtitles free browser...  [9251120-0]
# 1     9211589  [oh know getting late dont wan na go home im h...  [9211589-0]
# 2     9380845  [itiming subtitle uncontrollable lovebird team...  [9380845-0]
# 3     9301436  [ethereal music apiopensubtitlesorg deprecated...  [9301436-0]
# 4     9408707  [chris oh minibots yelling oh leave little bot...  [9408707-0]
# ...       ...                                                ...          ...
# 8245  9194538  [watch video online opensubtitles free browser...  [9194538-0]
# 8246  9461187  [hey twizzle meow hey twizzle twizzle girl huh...  [9461187-0]
# 8247  9309873  [script info title english u original script t...  [9309873-0]
# 8248  9255721  [life span link eternity begun must end advert...  [9255721-0]
# 8249  9485784  [advertise product brand contact wwwopensubtit...  [9485784-0]
#
#                                              embeddings
# 0     [[0.008589413948357105, -0.08819494396448135, ...
# 1     [[0.09815378487110138, -0.08552570641040802, 0...
# 2     [[0.27235913276672363, -0.10438156127929688, 0...
# 3     [[0.22709397971630096, 0.060651995241642, 0.02...
# 4     [[-0.151687353849411, -0.15321648120880127, 0....
# ...                                                 ...
# 8245  [[-0.12424875050783157, 0.029957635328173637, ...
# 8246  [[0.07549671828746796, -0.03596583753824234, 0...
# 8247  [[-0.08611387014389038, 0.06799688935279846, -...
# 8248  [[-0.18428510427474976, 0.16856567561626434, 0...
# 8249  [[-0.08873333781957626, 0.09661462903022766, 0...
#
# [8250 rows x 4 columns]

# %%
df["embeddings"][0]
# Out:
# C:\Users\shetk\AppData\Local\Temp\ipykernel_17300\460714602.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df["embeddings"][0]
# [[0.008589413948357105,
#   -0.08819494396448135,
#   0.3474327325820923,
#   0.04450773820281029,
#   -0.13636669516563416,
#   -0.027391467243433,
#   0.4440867602825165,
#   -0.22191067039966583,
#   -0.04648255929350853,
#   -0.05163887143135071,
#   -0.017414862290024757,
#   0.02495034597814083,
#   0.13749660551548004,
#   0.07140470296144485,
#   -0.14921823143959045,
#   0.08758902549743652,
#   0.1677783727645874,
#   0.14777332544326782,
#   0.07618239521980286,
#   0.18247151374816895,
#   0.02071760967373848,
#   -0.21852253377437592,
#   0.07975809276103973,
#   0.0476725697517395,
#   -0.10989607125520706,
#   -0.1418619304895401,
#   0.09663974493741989,
#   0.20419131219387054,
#   0.11492633819580078,
#   -0.041010405868291855,
#   0.1857718974351883,
#   0.14292101562023163,
#   -0.06957104802131653,
#   0.0025930972769856453,
#   0.04487820714712143,
#   -0.0954572781920433,
#   -0.13995306193828583,
#   -0.270480215549469,
#   -0.10864361375570297,
#   -0.04571092873811722,
#   0.06139260530471802,
#   -0.02180173620581627,
#   -0.1480872482061386,
#   -0.2695395350456238,
#   0.0441773347556591,
#   -0.04375087097287178,
#   -0.112640880048275,
#   0.11840104311704636,
#   0.017901815474033356,
#   0.11028852313756943,
#   0.13202373683452606,
#   -0.08688978105783463,
#   -0.18767386674880981,
#   -0.06952988356351852,
#   0.0982334315776825,
#   -0.08525429666042328,
#   0.010659717954695225,
#   0.01974448189139366,
#   -0.16383709013462067,
#   -0.07217521220445633,
#   0.05081581696867943,
#   -0.02916080504655838,
#   0.031297456473112106,
#   0.10646370053291321,
#   -0.01420115027576685,
#   0.013707253150641918,
#   -0.025941910222172737,
#   -0.06178225949406624,
#   -0.12635774910449982,
#   0.19874286651611328,
#   0.049018241465091705,
#   -0.007911228574812412,
#   -0.018114766106009483,
#   -0.03404862433671951,
#   -0.04633009433746338,
#   -0.032315779477357864,
#   0.10501646995544434,
#   -0.0744905173778534,
#   0.045467544347047806,
#   0.15608219802379608,
#   0.07823061943054199,
#   -0.1905772089958191,
#   0.08967000246047974,
#   -0.21971674263477325,
#   -0.09077908843755722,
#   0.040641169995069504,
#   0.03330413997173309,
#   0.2541664242744446,
#   -0.08499564975500107,
#   0.14270925521850586,
#   -0.1365889012813568,
#   -0.15343038737773895,
#   0.045646343380212784,
#   0.028998887166380882,
#   0.10510944575071335,
#   0.08552318811416626,
#   -0.015918470919132233,
#   -0.09801159054040909,
#   0.07113168388605118,
#   -0.11644291877746582,
#   0.03770287707448006,
#   -0.04872693121433258,
#   0.025791708379983902,
#   -0.09849782288074493,
#   -0.0674714744091034,
#   0.11248992383480072,
#   0.04239382594823837,
#   -0.05268052965402603,
#   -0.3272603452205658,
#   0.21310904622077942,
#   -0.06200472638010979,
#   0.08395009487867355,
#   0.07379094511270523,
#   0.25711750984191895,
#   0.2830672264099121,
#   0.05918170139193535,
#   0.060831986367702484,
#   0.18942734599113464,
#   0.12169257551431656,
#   0.273429811000824,
#   0.12974531948566437,
#   -0.15664547681808472,
#   -0.013716811314225197,
#   -0.006254231557250023,
#   -0.13228678703308105,
#   0.04513206705451012,
#   -0.19395580887794495,
#   0.25446319580078125,
#   0.21008388698101044,
#   0.05459895357489586,
#   -0.14061172306537628,
#   -0.09299765527248383,
#   -0.2181852161884308,
#   0.03764107823371887,
#   -0.019899636507034302,
#   0.2606004476547241,
#   -0.1670892834663391,
#   0.04499796777963638]]

# %% [markdown]
# ### Storing Data in Chromadb

# %% [markdown]
# #### Setting up chromadb

# %%
pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-0.5.0-py3-none-any.whl (526 kB)
#      ------------------------------------ 526.8/526.8 kB 393.4 kB/s eta 0:00:00
# Collecting opentelemetry-api>=1.2.0
#   Downloading opentelemetry_api-1.24.0-py3-none-any.whl (60 kB)
#      ---------------------------------------- 60.1/60.1 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\shetk\anaconda3\lib\site-packages (from chromadb) (0.19.1)
# Requirement already satisfied: requests>=2.28 in c:\users\shetk\anaconda3\lib\site-packages (from chromadb) (2.28.1)
# Requirement already satisfied: importlib-resources in c:\users\shetk\anaconda3\lib\site-packages (from chromadb) (6.1.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\shetk\anaconda3\lib\site-packages (from chromadb) (6.0)
# Collecting uvicorn[standard]>=0.18.3
#   Downloading uvicorn-0.29.0-py3-none-any.whl (60 kB)
#      ---------------------------------------- 60.8/60.8 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.5 in c:\users\shetk\anaconda3\lib\site-packages (from chromadb) (1.24.4)
# Collecting chroma-hnswlib==0.7.3
#   Downloading chroma_hnswlib-0.7.3-cp39-cp39-win_amd64.whl (150 kB)
#      -------------------------------------- 150.6/150.6 kB 1.1 MB/s eta 0:00:00
# Collecting orjson>=3.9.12
#   Downloading orjson-3.10.1-cp39-none-win_amd64.whl (138 kB)
#      ------------------------------------ 138.9/138.9 kB 748.2 kB/s eta 0:00:00
# Collecting onnxruntime>=1.14.1
#   Downloading onnxruntime-1.17.3-cp39-cp39-win_amd64.whl (5.6 MB)
#      ---------------------------------------- 5.6/5.6 MB 933.9 kB/s eta 0:00:00
# Collecting bcrypt>=4.0.1
#   Downloading bcrypt-4.1.2-cp39-abi3-win_amd64.whl (158 kB)
#      ------------------------------------ 158.3/158.3 kB 787.6 kB/s eta 0:00:00
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\shetk\anaconda3\lib\site-packages (from chromadb) (1.59.0)
# Collecting opentelemetry-sdk>=1.2.0
#   Downloading opentelemetry_sdk-1.24.0-py3-none-any.whl (106 kB)
#      -------------------------------------- 106.1/106.1 kB 6.4 MB/s eta 0:00:00
# Collecting posthog>=2.4.0
#   Downloading posthog-3.5.0-py2.py3-none-any.whl (41 kB)
#      ---------------------------------------- 41.3/41.3 kB 1.9 MB/s eta 0:00:00
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.24.0-py3-none-any.whl (18 kB)
# Collecting build>=1.0.3
#   Downloading build-1.2.1-py3-none-any.whl (21 kB)
# Collecting overrides>=7.3.1
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\shetk\anaconda3\lib\site-packages (from chromadb) (4.11.0)
# Collecting fastapi>=0.95.2
#   Downloading fastapi-0.110.2-py3-none-any.whl (91 kB)
#      ---------------------------------------- 91.9/91.9 kB 5.1 MB/s eta 0:00:00
# Collecting tqdm>=4.65.0
#   Using cached tqdm-4.66.2-py3-none-any.whl (78 kB)
# Requirement already satisfied: pydantic>=1.9 in c:\users\shetk\anaconda3\lib\site-packages (from chromadb) (1.10.13)
# Collecting tenacity>=8.2.3
#   Using cached tenacity-8.2.3-py3-none-any.whl (24 kB)
# Collecting mmh3>=4.0.1
#   Downloading mmh3-4.1.0-cp39-cp39-win_amd64.whl (31 kB)
# Collecting pypika>=0.48.9
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ---------------------------------------- 67.3/67.3 kB 1.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0
#   Downloading opentelemetry_instrumentation_fastapi-0.45b0-py3-none-any.whl (11 kB)
# Collecting kubernetes>=28.1.0
#   Downloading kubernetes-29.0.0-py2.py3-none-any.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 1.1 MB/s eta 0:00:00
# Collecting typer>=0.9.0
#   Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#      ---------------------------------------- 47.2/47.2 kB ? eta 0:00:00
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\shetk\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (4.11.3)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\shetk\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: packaging>=19.1 in c:\users\shetk\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (21.3)
# Collecting pyproject_hooks
#   Downloading pyproject_hooks-1.0.0-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: colorama in c:\users\shetk\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.5)
# Collecting starlette<0.38.0,>=0.37.2
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      ---------------------------------------- 71.9/71.9 kB ? eta 0:00:00
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\shetk\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.23.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\shetk\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.26.11)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\shetk\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2022.9.14)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\shetk\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: requests-oauthlib in c:\users\shetk\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\shetk\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\shetk\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: six>=1.9.0 in c:\users\shetk\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ---------------------------------------- 46.0/46.0 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: sympy in c:\users\shetk\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.10.1)
# Requirement already satisfied: protobuf in c:\users\shetk\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (4.24.3)
# Requirement already satisfied: flatbuffers in c:\users\shetk\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Collecting importlib-metadata>=4.6
#   Downloading importlib_metadata-7.0.0-py3-none-any.whl (23 kB)
# Collecting deprecated>=1.2.6
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting opentelemetry-proto==1.24.0
#   Downloading opentelemetry_proto-1.24.0-py3-none-any.whl (50 kB)
#      ---------------------------------------- 50.8/50.8 kB ? eta 0:00:00
# Collecting opentelemetry-exporter-otlp-proto-common==1.24.0
#   Downloading opentelemetry_exporter_otlp_proto_common-1.24.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\shetk\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.60.0)
# Collecting opentelemetry-instrumentation==0.45b0
#   Downloading opentelemetry_instrumentation-0.45b0-py3-none-any.whl (28 kB)
# Collecting opentelemetry-semantic-conventions==0.45b0
#   Downloading opentelemetry_semantic_conventions-0.45b0-py3-none-any.whl (36 kB)
# Collecting opentelemetry-util-http==0.45b0
#   Downloading opentelemetry_util_http-0.45b0-py3-none-any.whl (6.9 kB)
# Collecting opentelemetry-instrumentation-asgi==0.45b0
#   Downloading opentelemetry_instrumentation_asgi-0.45b0-py3-none-any.whl (14 kB)
# Requirement already satisfied: setuptools>=16.0 in c:\users\shetk\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (63.4.1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\shetk\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Collecting asgiref~=3.0
#   Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Collecting monotonic>=1.5
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\shetk\anaconda3\lib\site-packages (from requests>=2.28->chromadb) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shetk\anaconda3\lib\site-packages (from requests>=2.28->chromadb) (3.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\shetk\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.22.2)
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting rich>=10.11.0
#   Using cached rich-13.7.1-py3-none-any.whl (240 kB)
# Requirement already satisfied: click>=8.0.0 in c:\users\shetk\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.0.4)
# Requirement already satisfied: h11>=0.8 in c:\users\shetk\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Collecting httptools>=0.5.0
#   Downloading httptools-0.6.1-cp39-cp39-win_amd64.whl (60 kB)
#      ---------------------------------------- 60.2/60.2 kB 3.3 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting watchfiles>=0.13
#   Downloading watchfiles-0.21.0-cp39-none-win_amd64.whl (280 kB)
#      -------------------------------------- 280.0/280.0 kB 1.7 MB/s eta 0:00:00
# Collecting websockets>=10.4
#   Downloading websockets-12.0-cp39-cp39-win_amd64.whl (124 kB)
#      -------------------------------------- 125.0/125.0 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=3.1.0 in c:\users\shetk\anaconda3\lib\site-packages (from importlib-resources->chromadb) (3.8.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\shetk\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\shetk\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\shetk\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: filelock in c:\users\shetk\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.6.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\shetk\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.3.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\shetk\anaconda3\lib\site-packages (from packaging>=19.1->build>=1.0.3->chromadb) (3.0.9)
# Collecting pygments<3.0.0,>=2.13.0
#   Using cached pygments-2.17.2-py3-none-any.whl (1.2 MB)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\users\shetk\anaconda3\lib\site-packages (from starlette<0.38.0,>=0.37.2->fastapi>=0.95.2->chromadb) (3.5.0)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      -------------------------------------- 86.8/86.8 kB 490.7 kB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in c:\users\shetk\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.2.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\shetk\anaconda3\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.38.0,>=0.37.2->fastapi>=0.95.2->chromadb) (1.2.0)
# Collecting pyreadline3
#   Downloading pyreadline3-3.4.1-py3-none-any.whl (95 kB)
#      ---------------------------------------- 95.2/95.2 kB 5.3 MB/s eta 0:00:00
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\shetk\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml): started
#   Building wheel for pypika (pyproject.toml): finished with status 'done'
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53835 sha256=35d410d94a881e69b1688c195b1df30180165df6b146018174793fc9c643304a
#   Stored in directory: c:\users\shetk\appdata\local\pip\cache\wheels\f7\02\64\d541eac67ec459309d1fb19e727f58ecf7ffb4a8bf42d4cfe5
# Successfully built pypika
# Installing collected packages: pyreadline3, pypika, monotonic, mmh3, websockets, tqdm, tenacity, shellingham, python-dotenv, pyproject_hooks, pygments, overrides, orjson, opentelemetry-util-http, opentelemetry-semantic-conventions, opentelemetry-proto, mdurl, importlib-metadata, humanfriendly, httptools, deprecated, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, uvicorn, starlette, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, markdown-it-py, coloredlogs, build, rich, opentelemetry-sdk, opentelemetry-instrumentation, onnxruntime, kubernetes, fastapi, typer, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.1
#     Uninstalling tqdm-4.64.1:
#       Successfully uninstalled tqdm-4.64.1
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.0.1
#     Uninstalling tenacity-8.0.1:
#       Successfully uninstalled tenacity-8.0.1
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.11.2
#     Uninstalling Pygments-2.11.2:
#       Successfully uninstalled Pygments-2.11.2
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.11.3
#     Uninstalling importlib-metadata-4.11.3:
#       Successfully uninstalled importlib-metadata-4.11.3
#   Attempting uninstall: bcrypt
#     Found existing installation: bcrypt 3.2.0
#     Uninstalling bcrypt-3.2.0:
#       Successfully uninstalled bcrypt-3.2.0
# Successfully installed asgiref-3.8.1 backoff-2.2.1 bcrypt-4.1.2 build-1.2.1 chroma-hnswlib-0.7.3 chromadb-0.5.0 coloredlogs-15.0.1 deprecated-1.2.14 fastapi-0.110.2 httptools-0.6.1 humanfriendly-10.0 importlib-metadata-7.0.0 kubernetes-29.0.0 markdown-it-py-3.0.0 mdurl-0.1.2 mmh3-4.1.0 monotonic-1.6 onnxruntime-1.17.3 opentelemetry-api-1.24.0 opentelemetry-exporter-otlp-proto-common-1.24.0 opentelemetry-exporter-otlp-proto-grpc-1.24.0 opentelemetry-instrumentation-0.45b0 opentelemetry-instrumentation-asgi-0.45b0 opentelemetry-instrumentation-fastapi-0.45b0 opentelemetry-proto-1.24.0 opentelemetry-sdk-1.24.0 opentelemetry-semantic-conventions-0.45b0 opentelemetry-util-http-0.45b0 orjson-3.10.1 overrides-7.7.0 posthog-3.5.0 pygments-2.17.2 pypika-0.48.9 pyproject_hooks-1.0.0 pyreadline3-3.4.1 python-dotenv-1.0.1 rich-13.7.1 shellingham-1.5.4 starlette-0.37.2 tenacity-8.2.3 tqdm-4.66.2 typer-0.12.3 uvicorn-0.29.0 watchfiles-0.21.0 websockets-12.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.2.2 requires pyqt5<5.13, which is not installed.
# spyder 5.2.2 requires pyqtwebengine<5.13, which is not installed.
# anaconda-project 0.11.1 requires ruamel-yaml, which is not installed.
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\shetk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\shetk\anaconda3\lib\site-packages)

# %%
import chromadb
client = chromadb.PersistentClient(path=r"C:\Users\shetk\OneDrive\Desktop\Innomatics_Internship\Task_9_Search Engine\Webapp_Hanna_Reference")
collection = client.get_or_create_collection(name="search_engine", metadata={"hnsw:space": "cosine"})
collection_2 = client.get_or_create_collection(name="search_engine_FileName", metadata={"hnsw:space": "cosine"})

# %% [markdown]
# #### Creating function to add filenames of our subtitles¶

# %%
client = chromadb.PersistentClient(path=r"C:\Users\shetk\OneDrive\Desktop\Innomatics_Internship\Task_9_Search Engine\Webapp_Hanna_Reference") #_test_db
collection = client.get_collection(name="search_engine") #test_collection
collection_name = client.get_collection(name="search_engine_FileName")
model_name="paraphrase-MiniLM-L3-V2"
model = SentenceTransformer(model_name, device="cpu")

# %% [markdown]
# ### Creating function to add the chunks, embeddings and unique identifiers for our subtitle files

# %%
# Ran this part already before splitting data into 2 temporary dataframes
def add_func_v1():
    for i in range(df.shape[0]): #setting the range as total no. of rows in dataframe
        collection_2.add(
            documents=[df['name'].iloc[i]], # adding each filename
            embeddings=[[1,2,34,45]], # adding a random data, as we don't need it when retrieving file_name
            ids=[df['num'].iloc[i]] # entering unique 'num' id
        )
